# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/project-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: torch in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 2)) (2.1.2)
# Requirement already satisfied: torchvision in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 3)) (0.16.2)
# Collecting torchaudio (from -r ./requirements.txt (line 4))
#   Downloading torchaudio-2.9.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# Requirement already satisfied: scikit-learn in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 5)) (1.3.2)
# Requirement already satisfied: pandas in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 6)) (2.1.4)
# Requirement already satisfied: numpy in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: matplotlib in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 8)) (3.8.4)
# Requirement already satisfied: filelock in /root/venv/lib/python3.11/site-packages (from torch->-r ./requirements.txt (line 2)) (3.20.0)
# Requirement already satisfied: typing-extensions in /root/venv/lib/python3.11/site-packages (from torch->-r ./requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: sympy in /root/venv/lib/python3.11/site-packages (from torch->-r ./requirements.txt (line 2)) (1.12)
# Requirement already satisfied: networkx in /root/venv/lib/python3.11/site-packages (from torch->-r ./requirements.txt (line 2)) (3.5)
# Requirement already satisfied: jinja2 in /root/venv/lib/python3.11/site-packages (from torch->-r ./requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec in /root/venv/lib/python3.11/site-packages (from torch->-r ./requirements.txt (line 2)) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /root/venv/lib/python3.11/site-packages (from torch->-r ./requirements.txt (line 2)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /root/venv/lib/python3.11/site-packages (from torch->-r ./requirements.txt (line 2)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /root/venv/lib/python3.11/site-packages (from torch->-r ./requirements.txt (line 2)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /root/venv/lib/python3.11/site-packages (from torch->-r ./requirements.txt (line 2)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /root/venv/lib/python3.11/site-packages (from torch->-r ./requirements.txt (line 2)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /root/venv/lib/python3.11/site-packages (from torch->-r ./requirements.txt (line 2)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /root/venv/lib/python3.11/site-packages (from torch->-r ./requirements.txt (line 2)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /root/venv/lib/python3.11/site-packages (from torch->-r ./requirements.txt (line 2)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /root/venv/lib/python3.11/site-packages (from torch->-r ./requirements.txt (line 2)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /root/venv/lib/python3.11/site-packages (from torch->-r ./requirements.txt (line 2)) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /root/venv/lib/python3.11/site-packages (from torch->-r ./requirements.txt (line 2)) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /root/venv/lib/python3.11/site-packages (from torch->-r ./requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /root/venv/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->-r ./requirements.txt (line 2)) (12.9.86)
# Requirement already satisfied: requests in /root/venv/lib/python3.11/site-packages (from torchvision->-r ./requirements.txt (line 3)) (2.32.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /root/venv/lib/python3.11/site-packages (from torchvision->-r ./requirements.txt (line 3)) (12.0.0)
# INFO: pip is looking at multiple versions of torchaudio to determine which version is compatible with other requirements. This could take a while.
#   Downloading torchaudio-2.8.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (7.2 kB)
#   Downloading torchaudio-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.6 kB)
#   Downloading torchaudio-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.6 kB)
#   Downloading torchaudio-2.6.0-cp311-cp311-manylinux1_x86_64.whl.metadata (6.6 kB)
#   Downloading torchaudio-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.4 kB)
#   Downloading torchaudio-2.5.0-cp311-cp311-manylinux1_x86_64.whl.metadata (6.4 kB)
#   Downloading torchaudio-2.4.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.4 kB)
# INFO: pip is still looking at multiple versions of torchaudio to determine which version is compatible with other requirements. This could take a while.
#   Downloading torchaudio-2.4.0-cp311-cp311-manylinux1_x86_64.whl.metadata (6.4 kB)
#   Downloading torchaudio-2.3.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.4 kB)
#   Downloading torchaudio-2.3.0-cp311-cp311-manylinux1_x86_64.whl.metadata (6.4 kB)
#   Downloading torchaudio-2.2.2-cp311-cp311-manylinux1_x86_64.whl.metadata (6.4 kB)
#   Downloading torchaudio-2.2.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.4 kB)
# INFO: This is taking longer than usual. You might need to provide the dependency resolver with stricter constraints to reduce runtime. See https://pip.pypa.io/warnings/backtracking for guidance. If you want to abort this run, press Ctrl + C.
#   Downloading torchaudio-2.2.0-cp311-cp311-manylinux1_x86_64.whl.metadata (6.4 kB)
#   Downloading torchaudio-2.1.2-cp311-cp311-manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: scipy>=1.5.0 in /root/venv/lib/python3.11/site-packages (from scikit-learn->-r ./requirements.txt (line 5)) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /root/venv/lib/python3.11/site-packages (from scikit-learn->-r ./requirements.txt (line 5)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /root/venv/lib/python3.11/site-packages (from scikit-learn->-r ./requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /root/venv/lib/python3.11/site-packages (from pandas->-r ./requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.11/site-packages (from pandas->-r ./requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.11/site-packages (from pandas->-r ./requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 8)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 8)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /root/venv/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 8)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /root/venv/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 8)) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /root/venv/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 8)) (3.2.5)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->-r ./requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/venv/lib/python3.11/site-packages (from jinja2->torch->-r ./requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /root/venv/lib/python3.11/site-packages (from requests->torchvision->-r ./requirements.txt (line 3)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /root/venv/lib/python3.11/site-packages (from requests->torchvision->-r ./requirements.txt (line 3)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/venv/lib/python3.11/site-packages (from requests->torchvision->-r ./requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /root/venv/lib/python3.11/site-packages (from requests->torchvision->-r ./requirements.txt (line 3)) (2025.10.5)
# Requirement already satisfied: mpmath>=0.19 in /root/venv/lib/python3.11/site-packages (from sympy->torch->-r ./requirements.txt (line 2)) (1.3.0)
# Downloading torchaudio-2.1.2-cp311-cp311-manylinux1_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 79.3 MB/s eta 0:00:00
# Installing collected packages: torchaudio
# Successfully installed torchaudio-2.1.2
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
